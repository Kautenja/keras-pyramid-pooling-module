# %%
from keras import backend as K
from keras.layers import Input
from keras.models import Model
from skimage import data
from PIL import Image
# Out:
# Using TensorFlow backend.

# %%
from keras_pyramid_pooling_module import PyramidPoolingModule

# %%
img = data.chelsea()
Image.fromarray(img)
# Out:
# <PIL.Image.Image image mode=RGB size=451x300 at 0x7FBED11B7C88>

# %%
K.clear_session()
input_ = Input(img.shape)
x = PyramidPoolingModule()(input_)
model = Model(inputs=input_, outputs=x)
# Out:
# (?, 1, 1, 3)
# (?, 151, 227, 3)
# (?, 201, 302, 3)
# (?, 251, 377, 3)

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 300, 451, 3)       0
# _________________________________________________________________
# pyramid_pooling_module_1 (Py (None, 300, 451, 7)       16
# ...
# Total params: 16
# Trainable params: 16
# Non-trainable params: 0
# _________________________________________________________________

# %%
out = model.predict(img[None, ...])

# %%
out.shape
# Out:
# (1, 300, 451, 7)

# %% [markdown]
# # Outputs

# %% [markdown]
# ## unmodified input

# %%
Image.fromarray(out[0, ..., :3].astype('uint8'))
# Out:
# <PIL.Image.Image image mode=RGB size=451x300 at 0x7FBEAAFCE860>

# %% [markdown]
# ## pyramid outputs

# %%
Image.fromarray(out[0, ..., 3].astype('uint8'))
# Out:
# <PIL.Image.Image image mode=L size=451x300 at 0x7FBEAAFCE8D0>

# %%
Image.fromarray(out[0, ..., 4].astype('uint8'))
# Out:
# <PIL.Image.Image image mode=L size=451x300 at 0x7FBEA8F6D6D8>

# %%
Image.fromarray(out[0, ..., 5].astype('uint8'))
# Out:
# <PIL.Image.Image image mode=L size=451x300 at 0x7FBEA8F6D240>

# %%
Image.fromarray(out[0, ..., 6].astype('uint8'))
# Out:
# <PIL.Image.Image image mode=L size=451x300 at 0x7FBEA8F6D0B8>
